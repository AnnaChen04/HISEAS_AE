# %% [markdown]
# # HISEAS LIG SST Visualization
# ### Elli S., Anna C., Jannik M.
# ### Updated on Feb 7, 2025

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.animation as animation
import math

# !pip install shapely
from shapely.geometry import Point

# !pip install geopandas
import geopandas as gpd
from geopandas import GeoDataFrame

# !pip install geodatasets
import geodatasets
# Out:
# Requirement already satisfied: shapely in /Users/anna/anaconda3/lib/python3.11/site-packages (2.0.7)
# Requirement already satisfied: numpy<3,>=1.14 in /Users/anna/anaconda3/lib/python3.11/site-packages (from shapely) (1.24.3)
# Requirement already satisfied: geopandas in /Users/anna/anaconda3/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /Users/anna/anaconda3/lib/python3.11/site-packages (from geopandas) (1.24.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/anna/anaconda3/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /Users/anna/anaconda3/lib/python3.11/site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in /Users/anna/anaconda3/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/anna/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Collecting geodatasets
#   Obtaining dependency information for geodatasets from https://files.pythonhosted.org/packages/9d/dd/e30e144271280d263c0c10f34fbcf2e09e9a82bd11a165c5f1f498899a29/geodatasets-2024.8.0-py3-none-any.whl.metadata
#   Downloading geodatasets-2024.8.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting pooch (from geodatasets)
#   Obtaining dependency information for pooch from https://files.pythonhosted.org/packages/a8/87/77cc11c7a9ea9fd05503def69e3d18605852cd0d4b0d3b8f15bbeb3ef1d1/pooch-1.8.2-py3-none-any.whl.metadata
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pooch->geodatasets) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pooch->geodatasets) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pooch->geodatasets) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in
# 24   26.00   26.00  ...   27.10   27.10   27.00   27.00   26.90   26.80
# 25   20.80   20.80  ...   21.20   21.20   21.20   21.20   21.10   21.10
# 26   16.90   16.90  ...   16.00   15.90   15.90   15.80   15.80   15.70
# 27   25.50   25.50  ...   24.30   24.20   24.10   24.10   24.10   24.00
# 28   25.20   25.30  ...   24.50   24.50   24.50   24.40   24.40   24.40
# 29   25.70   25.70  ...   25.60   25.60   25.60   25.60   25.60   25.60
# 30   21.10   21.10  ...   23.60   23.50   23.40   23.40   23.20   23.00
# 31   26.00   26.00  ...   26.90   26.80   26.80   26.80   26.70   26.70
# 32   26.30   26.30  ...   26.40   26.30   26.30   26.30   26.30   26.20
# 33   25.40   25.40  ...   25.50   25.40   25.40   25.40   25.40   25.40
#
#     129700  129800  129900  130000
# 0     2.75    2.77    2.74    2.69
# 1     7.00    7.50    7.60    6.50
# 2     4.99    4.87    4.70    4.58
# 3     8.85    8.70    8.60    8.60
# 4     7.18    6.95    6.84    6.76
# 5    13.84   13.72   13.55   13.37
# 6     8.69    8.46    8.22    7.99
# 7     7.43    7.22    6.95    6.76
# 8    16.08   16.08   16.02   16.17
# 9     3.88    3.81    3.75    3.74
# 10    9.10    8.70    8.20    7.90
# 11   10.30   10.40   10.60   10.70
# 12   11.20   11.20   11.10   11.00
# 13    9.30    9.10    9.00    8.80
# 14   15.60   15.60   15.50   15.40
# 15   13.70   13.70   13.60   13.50
# 16   14.70   14.50   14.40   14.20
# 17   11.90   11.80   11.70   11.70
# 18   10.40   10.40   10.50   10.60
# 19   18.20   18.10   18.00   18.00
# 20   15.90   15.30   14.90   14.70
# 21   20.60   20.50   20.40   20.30
# 22   23.50   23.40   23.30   23.30
# 23   23.80   23.70   23.70   23.60
# 24   26.80   26.70   26.70   26.60
# 25   21.10   21.10   21.10   21.10
# 26   15.60   15.60   15.50   15.40
# 27   24.00   23.90   23.90   23.80
# 28   24.30   24.30   24.30   24.20
# 29   25.60   25.60   25.60   25.60
# 30   22.90   22.80   22.60   22.40
# 31   26.60   26.60   26.50   26.50
# 32   26.20   26.10   26.10   26.10
# 33   25.30   25.30   25.40   25.30
#
# [34 rows x 155 columns]

# %%
# Create GeoDataFrame
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)

# Load world map
world = gpd.read_file(geodatasets.data.naturalearth.land['url'])

# Define marker styles for each proxy type
proxy_marker_map = {
    "Foram": "o",  # Circle
    "UK37": "^",    # Triangle
    "MgCa": "s"     # Square
}

# Extract temperature values
temperature_values = df["115000"]

# Normalize temperature values for colormap
norm = plt.Normalize(vmin=temperature_values.min(), vmax=temperature_values.max())
cmap = plt.cm.coolwarm  # Choose a colormap

# Plot Map
fig, ax = plt.subplots(figsize=(10, 6))
world.plot(ax=ax, color='lightgray')

# Plot each proxy type with different markers and colormap
for proxy, marker in proxy_marker_map.items():
    subset = gdf[gdf['Proxy'] == proxy]
    
    # Scatter plot with color based on temperature
    scatter = ax.scatter(
        subset['Longitude'], subset['Latitude'],
        marker=marker, 
        c=subset["115000"],  # Color by temperature
        cmap=cmap, norm=norm, 
        edgecolor="black", s=50, label=proxy
    )

# Add colorbar
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label("Temperature (°C)")
# Add legend
plt.legend(title="Proxy Type")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Hoffman Temperature Visualization 115kya")

plt.show()

# %%
# create line plots comparing same location different proxies temperature
fig, ax = plt.subplots(figsize=(10,6))
plt.plot(

# %%
years = np.arange(115000, 130100, 100).astype(str)
years

# Normalize temperature values for colormap
all_temps = df[years].values.flatten()
norm = plt.Normalize(vmin=np.nanmin(all_temps), vmax=np.nanmax(all_temps))
cmap = plt.cm.viridis

# %%
# Create Figure and Axis
fig, ax = plt.subplots(figsize=(10, 6))
world.plot(ax=ax, color='lightgray')

# Initialize scatter plots for each proxy type
scatter_plots = {}
for proxy, marker in proxy_marker_map.items():
    subset = gdf[gdf['Proxy'] == proxy]
    scatter_plots[proxy] = ax.scatter(
        subset['Longitude'], subset['Latitude'],
        marker=marker, cmap=cmap, norm=norm,
        edgecolor="black", s=50, label=proxy
    )

# Add colorbar
cbar = plt.colorbar(scatter_plots["Foram"], ax=ax)
cbar.set_label("Temperature (°C)")

# Add legend for proxy types
plt.legend(title="Proxy Type")

# Set labels
plt.xlabel("Longitude")
plt.ylabel("Latitude")
title = plt.title(f"Temperature Change Over Time - Year {years[0]}")

# Update function for animation
def update(frame):
    year = years[frame]
    title.set_text(f"Temperature Change Over Time - Year {year}")

    for proxy, scatter in scatter_plots.items():
        subset = gdf[gdf['Proxy'] == proxy]
        scatter.set_array(subset[year])  # Update colors based on the new year

    return scatter_plots.values()

# Create Animation
ani = animation.FuncAnimation(fig, update, frames=len(years), interval=500, blit=False)

# Show Animation
plt.show()
# Out:
# /var/folders/z1/qxyx9p114qn5g8pjhv3f78j40000gn/T/ipykernel_65571/2385574423.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   scatter_plots[proxy] = ax.scatter(
# /var/folders/z1/qxyx9p114qn5g8pjhv3f78j40000gn/T/ipykernel_65571/2385574423.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   scatter_plots[proxy] = ax.scatter(
# /var/folders/z1/qxyx9p114qn5g8pjhv3f78j40000gn/T/ipykernel_65571/2385574423.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   scatter_plots[proxy] = ax.scatter(

# %%
# Extract years from column names (everything after 'Proxy')
years = [col for col in df.columns if col.isdigit()]  # Extract numerical columns (years)
#years = sorted(years, key=int)  # Sort years numerically
# Out:
# []
